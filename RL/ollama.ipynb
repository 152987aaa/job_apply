# %%
from ollama import chat
from ollama import ChatResponse

response: ChatResponse = chat(model='deepseek-r1:7b', messages=[
  {
    'role': 'user',
    'content': '为什么天空是蓝色的？',
  },
])
print(response['message']['content'])

print(response.message.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[1], line 4
#       1 from ollama import chat
#       2 from ollama import ChatResponse
# ----> 4 response: ChatResponse = chat(model='deepseek-r1:7b', messages=[
#       5   {
#       6     'role': 'user',
#       7     'content': '为什么天空是蓝色的？',
#       8   },
#       9 ])
#      10 print(response['message']['content'])
#      12 print(response.message.content)
#
# File D:\Users\13535\anaconda3\envs\pytorch\Lib\site-packages\ollama\_client.py:387, in Client.chat(self, model, messages, tools, stream, think, logprobs, top_logprobs, format, options, keep_alive)
#     340 def chat(
#     341   self,
#     342   model: str = '',
#    (...)    352   keep_alive: Optional[Union[float, str]] = None,
#     353 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     354   """
#     355   Create a chat response using the requested model.
#     356
#    (...)    385   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     386   """
# --> 387   return self._request(
#     388     ChatResponse,
#     389     'POST',
#     390     '/api/chat',
#     391     json=ChatRequest(
#     392       model=model,
#     393       messages=list(_copy_messages(messages)),
#     394       tools=list(_copy_tools(tools)),
#     395       stream=stream,
#     396       think=think,
#     397       logprobs=logprobs,
#     398       top_logprobs=top_logprobs,
#     399       format=format,
#     400       options=options,
#     401       keep_alive=keep_alive,
#     402     ).model_dump(exclude_none=True),
#     403     stream=stream,
#     404   )
#
# File D:\Users\13535\anaconda3\envs\pytorch\Lib\site-packages\ollama\_client.py:199, in Client._request(self, cls, stream, *args, **kwargs)
#     195         yield cls(**part)
#     197   return inner()
# --> 199 return cls(**self._request_raw(*args, **kwargs).json())
#
# File D:\Users\13535\anaconda3\envs\pytorch\Lib\site-packages\ollama\_client.py:143, in Client._request_raw(self, *args, **kwargs)
#     141   return r
#     142 except httpx.HTTPStatusError as e:
# --> 143   raise ResponseError(e.response.text, e.response.status_code) from None
#     144 except httpx.ConnectError:
#     145   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError:  (status code: 502)

# %%
from ollama import Client
from ollama import ChatResponse

# 关键！必须连对地址！
client = Client(host="http://localhost:11434")  # 这是你电脑本地的 Ollama

response: ChatResponse = client.chat(
    model='deepseek-r1:7b',
    messages=[
        {
            'role': 'user',
            'content': '为什么天空是蓝色的？',
        },
    ]
)

print(response['message']['content'])
# Out:
# 天空呈现蓝色主要归功于太阳光和地球大气层相互作用的结果：
#
# 1. **白光组成**：太阳发出的光是一种复合色，包含了红、橙、黄、绿、蓝、靛、紫七种颜色，其中蓝色的光具有较短波长。
#
# 2. **散射现象**：
#    - 大气中的分子和颗粒物对不同波长的光有不同的影响。
#    - 波长短（如蓝色）在大气中被散射得更多，从而使光线向各个方向传播。
#
# 3. **结果呈现蓝色天空**：由于蓝色光能够更广泛地穿透大气层并均匀分布于各个方向，我们从各个角度看天都呈现为蓝色。
#
# 4. **云的影响**：云中的颗粒物对不同颜色的光吸收和散射有影响，但通常不会显著改变整体天空的颜色。
#
# 5. **日出日落现象**：太阳离地角较大时，阳光穿过大气层的距离较短，蓝色更容易穿透，导致日出、日落时天色更深蓝。
#
# 总结来说，天空呈现蓝色是因为阳光中的蓝色光在地球大气层中被更多地散射和穿透所致。
